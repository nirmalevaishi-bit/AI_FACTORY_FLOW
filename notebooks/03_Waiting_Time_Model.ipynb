# %% [markdown]
# # Stage 11 - Waiting Time Prediction
#
# ## Project
#
# AI-Based Smart Factory Flow Optimizer
#
# ## Model
#
# Random Forest Regressor
#
# ## Objective
#
# Predict Expected Waiting Time.

# %%
import pandas as pd

from sklearn.model_selection import train_test_split

from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

import joblib

# %%
df = pd.read_csv("../data/processed/final_factory_data.csv")

# %%
df.head()
# Out:
#   Product_ID   Machine_ID Machine_Status  Queue_Length  Processing_Time  \
# 0      P0328     Lathe_M1           Busy             6               33
# 1      P0347     Lathe_M1    Maintenance            20               43
# 2      P0259     Lathe_M1           Idle            10               28
# 3      P0389  Grinding_M2    Maintenance             2               26
# 4      P0053     Lathe_M1    Maintenance             5                6
#
#   Worker_Available    Shift         Material_Type  Temperature  \
# 0               No  Morning  Bearing_Steel_Chrome           39
# 1              Yes  Morning  Bearing_Steel_Chrome           82
# 2               No  Morning     Bearing_Stainless           77
# 3               No  Evening  Bearing_Steel_Chrome           77
# 4              Yes  Evening     Bearing_Stainless           84
#
#    Previous_Wait_Time  ...  Next_Machine Recommended_Machine  \
# 0                  12  ...  Polishing_M3            Lathe_M1
# ...

# %%
features = [
    "Queue_Length",
    "Processing_Time",
    "Temperature",
    "Previous_Wait_Time",
    "Current_Wait_Time",
    "Worker_Status",
    "Machine_Load",
    "Shift_Code",
    "Bottleneck_Flag"
]

X = df[features]

# %%
y = df["Expected_Waiting_Time"]

# %%
print(df.shape)
# Out:
# (5000, 21)

# %%
print(X.shape)
# Out:
# (5000, 9)

# %%
print(y.shape)
# Out:
# (5000,)

# %%
print(df.head())
print(df.shape)
# Out:
#   Product_ID   Machine_ID Machine_Status  Queue_Length  Processing_Time  \
# 0      P0328     Lathe_M1           Busy             6               33
# 1      P0347     Lathe_M1    Maintenance            20               43
# 2      P0259     Lathe_M1           Idle            10               28
# 3      P0389  Grinding_M2    Maintenance             2               26
# 4      P0053     Lathe_M1    Maintenance             5                6
#
#   Worker_Available    Shift         Material_Type  Temperature  \
# 0               No  Morning  Bearing_Steel_Chrome           39
# 1              Yes  Morning  Bearing_Steel_Chrome           82
# 2               No  Morning     Bearing_Stainless           77
# 3               No  Evening  Bearing_Steel_Chrome           77
# 4              Yes  Evening     Bearing_Stainless           84
#
#    Previous_Wait_Time  ...  Next_Machine Recommended_Machine  \
# 0                  12  ...  Polishing_M3            Lathe_M1
# ...

# %%
import pandas as pd

raw_df = pd.read_csv("../data/raw/factory_flow_data.csv")

print(raw_df.shape)
# Out:
# (5000, 14)

# %%
clean_df = pd.read_csv("../data/processed/cleaned_factory_flow_data.csv")

print(clean_df.shape)
# Out:
# (5000, 14)
